# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/alura-cursos/credit_scoring/main/base_dados_traduzida.csv'
dados = pd.read_csv(url)

dados.head()
# Out:
#    default       conta_corrente  prazo_emprestimo_meses  \
# 0        0               < 0 DM                       6
# 1        1    0 <= ... < 200 DM                      48
# 2        0  no checking account                      12
# 3        0               < 0 DM                      42
# 4        1               < 0 DM                      24
#
#                                    historico_credito  \
# 0  critical account/ other credits existing (not ...
# 1           existing credits paid back duly till now
# 2  critical account/ other credits existing (not ...
# 3           existing credits paid back duly till now
# 4                    delay in paying off in the past
#
#            proposito_emprestimo  valor_emprestimo  \
# 0           domestic appliances              1169
# 1           domestic appliances              5951
# 2  (vacation - does not exist?)              2096
# 3              radio/television              7882
# ...

# %%
y = dados['default']
y.head()

x = dados.drop(columns = 'default')
x.head()
# Out:
#         conta_corrente  prazo_emprestimo_meses  \
# 0               < 0 DM                       6
# 1    0 <= ... < 200 DM                      48
# 2  no checking account                      12
# 3               < 0 DM                      42
# 4               < 0 DM                      24
#
#                                    historico_credito  \
# 0  critical account/ other credits existing (not ...
# 1           existing credits paid back duly till now
# 2  critical account/ other credits existing (not ...
# 3           existing credits paid back duly till now
# 4                    delay in paying off in the past
#
#            proposito_emprestimo  valor_emprestimo  \
# 0           domestic appliances              1169
# 1           domestic appliances              5951
# 2  (vacation - does not exist?)              2096
# 3              radio/television              7882
# 4                     car (new)              4870
#
# ...

# %%
from sklearn.model_selection import train_test_split

SEED = 77
treino_x, teste_x,  treino_y, teste_y = train_test_split(x, y, test_size = 0.30, random_state = SEED)

base_treino = treino_x.shape[0]
base_teste = teste_x.shape[0]

print(base_treino)
print(base_teste)
# Out:
# 700
# 300

# %%
dados['conta_corrente'].unique()

a = {
    '< 0 DM' :1,
    '0 <= ... < 200 DM' : 2,
    'no checking account' : 3,
    '>= 200 DM / salary assignments for at least 1 year' : 4
}

dados['conta_corrente'] = dados['conta_corrente'].map(a)

# %%
from sklearn.linear_model import LogisticRegression

modelo = LogisticRegression(max_iter=1000)
modelo.fit(treino_x, treino_y)
print(modelo.score(treino_x, treino_y))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-40f04e4ffc09> in <cell line: 4>()
#       2
#       3 modelo = LogisticRegression(max_iter=1000)
# ----> 4 modelo.fit(treino_x, treino_y)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1150                 )
#    1151             ):
# -> 1152                 return fit_method(estimator, *args, **kwargs)
#    1153
#    1154         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1206             _dtype = [np.float64, np.float32]
#    1207
# -> 1208         X, y = self._validate_data(
#    1209             X,
#    1210             y,
#
# ...

# %%
tfp, tvp, limite = roc_curve(teste_y, prob_previsao)

plt.subplots(1, figsize=(5,5))
plt.title('Curva ROC')
plt.plot(tfp, tvp)
plt.plot([0, 1], ls="--", c = 'red') #plotando linha pontilhada guia para regressao aleatoria
plt.plot([0, 0], [1, 0], ls="--", c = 'green'), plt.plot([1, 1], ls="--", c = 'green') #plotando linha pontilhada guia para regressao perfeita
plt.ylabel('Sensibilidade')
plt.xlabel('Especificidade')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(30,20))
sns.countplot('variavel1', data = dataframe)

import matplotlib.pyplot as plt
import seaborn as sns

histogramas = ['variavel1', 'variavel2', … ,  'variavelx']
lista_histogramas = list(enumerate(histogramas))

plt.figure(figsize=(30,20))

for i in lista_histogramas:
  plt.subplot(2, 2, i[0]+1)
  sns.countplot(x = i[1], data = dataframe)


  import matplotlib.pyplot as plt

plt.figure(figsize=(30,20))
plt.bar(dataframe.variavel1, dataframe.variavel2)

#incrementando o grafico
plt.xlabel('nome_eixo_x')
plt.ylabel('nome_eixo_y')
plt.title('Titulo')

plt.show()


import matplotlib.pyplot as plt
import seaborn as sns

sns.boxplot(x = 'variavel1', y = 'variavel2', data = dataframe)

#incrementando o grafico
plt.title('Distribuição de idade por sexo_est_civil')

plt.show()
