# %%
import pandas as pd
from datetime import datetime

uri = "https://gist.githubusercontent.com/guilhermesilveira/e99a526b2e7ccc6c3b70f53db43a87d2/raw/1605fc74aa778066bf2e6695e24d53cf65f2f447/machine-learning-carros-simulacao.csv"


ano_atual = datetime.today().year
dados['year'] = ano_atual - dados.model_year
dados['km'] = dados.mileage_per_year * 1.60934
dados.sold = dados.sold.map(a_trocar)

dados = dados.drop(columns= ["Unnamed: 0", "Unnamed: 0", "model_year"], axis=1)


x = dados[["km", "price", "year"]]
y = dados[["sold"]]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-39bcd53e1d58> in <cell line: 8>()
#       6
#       7 ano_atual = datetime.today().year
# ----> 8 dados['year'] = ano_atual - dados.model_year
#       9 dados['km'] = dados.mileage_per_year * 1.60934
#      10 dados.sold = dados.sold.map(a_trocar)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#    6205
#    6206     @final
#
# AttributeError: 'DataFrame' object has no attribute 'model_year'

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_validate


model = DecisionTreeClassifier(max_depth=3)
cross_validate(model, x, y, cv = 3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ef7a834d1f92> in <cell line: 6>()
#       4
#       5 modelo = DecisionTreeClassifier(max_depth=3)
# ----> 6 modelo.fit(raw_treino_x, treino_y)
#       7 previsoes = modelo.predict(raw_teste_x)
#
# NameError: name 'raw_treino_x' is not defined
